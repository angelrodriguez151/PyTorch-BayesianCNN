# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/emman/Documents/tablapesos.csv')

# %%
df.drop(['Unnamed: 0'], axis = 1)
# Out:
#            Pais_Out  Sector  Pais_In  Dem_Fin  Descomposicion   Ano      Peso
# 0                 0       0        0        0               0  1995  12344.00
# 1                 0       0        0        0               0  1995     25.67
# 2                 0       0        0        0               0  1995    768.00
# 3                 0       0        0        0               0  1995   3414.00
# 4                 0       0        0        0               0  1995   1048.00
# ...             ...     ...      ...      ...             ...   ...       ...
# 116354875        66      44       66        5               3  2018      0.00
# 116354876        66      44       66        5               3  2018      0.00
# 116354877        66      44       66        5               3  2018      0.00
# 116354878        66      44       66        5               3  2018      0.00
# 116354879        66      44       66        5               3  2018      0.00
#
# [116354880 rows x 7 columns]

# %%
df.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d87ea438e3dc> in <module>
# ----> 1 df['Descomposicion'] = df['Descomposicion'].astype('int4')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...
